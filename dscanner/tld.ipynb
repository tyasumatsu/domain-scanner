# %% [markdown]
# ### インポート

# %%
import re
import urllib
import pickle
from bs4 import BeautifulSoup

# %% [markdown]
# ### htmlを抜く

# %%
def get_soup(url):
    html = urllib.request.urlopen(url)
    soup = BeautifulSoup(html, "html.parser")
    return soup

# %% [markdown]
# ### ICANN公式のnew gTLDの一覧ページ

# %%
url = "https://newgtlds.icann.org/en/program-status/delegated-strings"
soup = get_soup(url)

# %%
NEW_TLD = []

# %%
for i, tld in enumerate(soup.find_all("td")):
    if i % 2 == 1:
        if not tld.find("span"):  
            tld = str(tld.text)
        else:
            tld = str(tld.contents[1])
        if "xn--" in tld:
            tld = [i for i in tld.split(" ") if "xn--" in i][0]
            if "(" in tld:
                tld = tld[tld.find("(") + 1: tld.find(")")]
        if "xn―cg4bki" in tld: # ICANN公式がtypoしているという、、
            tld = "xn--cg4bki"
        tld = tld.lower()
        NEW_TLD.append(tld)

# %%
len(NEW_TLD) # 1225個がnew gTLD
# Out:
# 1225

# %%
NEW_TLD
# Out:
# ['charity',
#  'llc',
#  'xn--otu796d',
#  'sport',
#  'merckmsd',
#  'search',
#  'phd',
#  'map',
#  'grocery',
#  'xn--mgbaakc7dvf',
#  'etisalat',
#  'arab',
#  'xn--ngbrx',
#  'rugby',
#  'hotels',
#  'africa',
#  'fun',
#  'phone',
#  'mobile',
#  'data',
#  'hospital',
#  'hair',
#  'xn--80aqecdr1a',
#  'xn--mgbi4ecexp',
#  'xn--tiq49xqyj',
#  'catholic',
#  'boston',
#  'rmit',
#  'reliance',
#  'jio',
#  'ril',
#  'moto',
#  'cruise',
#  'box',
#  'food',
#  'free',
#  'aol',
#  'newholland',
#  'baseball',
#  'caseih',
#  'case',
#  'iveco',
#  'volvo',
#  'basketball',
#  'radio',
#  'dvr',
#  'xn--gk3at1e',
#  'observer',
#  'wow',
#  'rogers',
#  'fido',
#  'monster',
#  'eco',
#  'vanguard',
#  'diy',
#  'samsclub',
#  'walmart',
#  'nab',
#  'george',
#  'ubank',
#  'auspost',
#  'xn--3oq18vl8pn36a',
#  'aigo',
#  'hdfc',
#  'hbo',
#  'asda',
#  'hot',
#  'pay',
#  'hughes',
#  'dish',
#  'capitalone',
#  'sling',
#  'secure',
#  'amex',
#  'open',
#  'americanexpress',
#  'loft',
#  'lancia',
#  'dodge',
#  'cbs',
#  'gap',
#  'qvc',
#  'maserati',
#  'oldnavy',
#  'bananarepublic',
#  'showtime',
#  'blockbuster',
#  'calvinklein',
#  'fidelity',
#  'target',
#  'abarth',
#  'athleta',
#  'latino',
#  'nba',
#  'fiat',
#  'mopar',
#  'juniper',
#  'ferrari',
#  'alfaromeo',
#  'bofa',
#  'lilly',
#  'mckinsey',
#  'afamilycompany',
#  'ladbrokes',
#  'uconnect',
#  'abc',
#  'hyatt',
#  'intel',
#  'glade',
#  'pru',
#  'jeep',
#  'srt',
#  'visa',
#  'banamex',
#  'prudential',
#  'pramerica',
#  'chrysler',
#  'discover',
#  'citi',
#  'americanfamily',
#  'honeywell',
#  'duns',
#  'msd',
#  'booking',
#  'amfam',
#  'esurance',
#  'citadel',
#  'duck',
#  'raid',
#  'swiftcover',
#  'scjohnson',
#  'ieee',
#  'off',
#  'doctor',
#  'rightathome',
#  'tiaa',
#  'lpl',
#  'lplfinancial',
#  'bestbuy',
#  'bbt',
#  'panasonic',
#  'beauty',
#  'lundbeck',
#  'tjx',
#  'smart',
#  'fujixerox',
#  'homesense',
#  'staples',
#  'marshalls',
#  'lancome',
#  'tkmaxx',
#  'homegoods',
#  'pfizer',
#  'vivo',
#  'winners',
#  'onyourside',
#  'tjmaxx',
#  'nationwide',
#  'goodhands',
#  'allstate',
#  'lefrak',
#  'macys',
#  'mint',
#  'intuit',
#  'ses',
#  'nike',
#  'xfinity',
#  'mitsubishi',
#  'comcast',
#  'godaddy',
#  'fujitsu',
#  'mit',
#  'shangrila',
#  'zippo',
#  'xn--5su34j936bgsg',
#  'cbre',
#  'ikano',
#  'pnc',
#  'farmers',
#  'fedex',
#  'politie',
#  'art',
#  'nfl',
#  'woodside',
#  'travelchannel',
#  'hgtv',
#  'frontdoor',
#  'foodnetwork',
#  'cookingchannel',
#  'orientexpress',
#  'anz',
#  'itv',
#  'blanco',
#  'shopping',
#  'able',
#  'cam',
#  'lego',
#  'alstom',
#  'dunlop',
#  'airbus',
#  'goodyear',
#  'kosher',
#  'dupont',
#  'ericsson',
#  'save',
#  'prime',
#  'deal',
#  'epost',
#  'now',
#  'chintai',
#  'fire',
#  'kindle',
#  'silk',
#  'imdb',
#  'audible',
#  'tdk',
#  'dhl',
#  'hisamitsu',
#  'games',
#  'pioneer',
#  'zappos',
#  'ups',
#  'mattel',
#  'netflix',
#  'ott',
#  'locker',
#  'dtv',
#  'ollo',
#  'mlb',
#  'realestate',
#  'shop',
#  'aetna',
#  'dot',
#  'blog',
#  'xn--w4rs40l',
#  'guardian',
#  'hkt',
#  'richardli',
#  'pccw',
#  'dds',
#  'nowtv',
#  'metlife',
#  'xn--fzys8d69uvgm',
#  'flir',
#  'olayangroup',
#  'xn--mgba7c0bbn0a',
#  'lipsy',
#  'olayan',
#  'nextdirect',
#  'warman',
#  'next',
#  'mls',
#  'progressive',
#  'ftr',
#  'xn--5tzm5g',
#  'statebank',
#  'sbi',
#  'agakhan',
#  'ismaili',
#  'akdn',
#  'imamat',
#  'teva',
#  'jnj',
#  'baby',
#  'vig',
#  'xn--9krt00a',
#  'weibo',
#  'abudhabi',
#  'xn--mgbca7dzdo',
#  'abbvie',
#  'northwesternmutual',
#  'kpmg',
#  'mutual',
#  'jcp',
#  'yun',
#  'shouji',
#  'nissay',
#  'sina',
#  'xihuan',
#  'anquan',
#  'talk',
#  'aws',
#  'you',
#  'xn--fct429k',
#  'extraspace',
#  'ally',
#  'barefoot',
#  'gallo',
#  'shaw',
#  'stream',
#  'locus',
#  'gmbh',
#  'avianca',
#  'bcg',
#  'total',
#  'kerryproperties',
#  'kerrylogistics',
#  'kuokgroup',
#  'xn--w4r85el8fhu5dnra',
#  'kerryhotels',
#  'vuelos',
#  'passagens',
#  'jpmorgan',
#  'chase',
#  'telecity',
#  'tunes',
#  'song',
#  'store',
#  'xn--jvr189m',
#  'viking',
#  'xn--bck1b9a5dre4c',
#  'xn--rovu88b',
#  'spot',
#  'xn--1ck2e1b',
#  'xn--cck2b3b',
#  'xn--gckr3f0f',
#  'coupon',
#  'yahoo',
#  'tvs',
#  'flickr',
#  'gallup',
#  'hdfcbank',
#  'pwc',
#  'wolterskluwer',
#  'natura',
#  'frontier',
#  'quest',
#  'xn--8y0a063a',
#  'unicom',
#  'deloitte',
#  'weatherchannel',
#  'nikon',
#  'lanxess',
#  'helsinki',
#  'health',
#  'adac',
#  'edeka',
#  'taobao',
#  'tmall',
#  'tiffany',
#  'lifeinsurance',
#  'xn--g2xx48c',
#  'alipay',
#  'alibaba',
#  'softbank',
#  'compare',
#  'skin',
#  'iselect',
#  'makeup',
#  'select',
#  'weather',
#  'tube',
#  'fresenius',
#  'volkswagen',
#  'dubai',
#  'baidu',
#  'promo',
#  'living',
#  'clinique',
#  'lamer',
#  'safety',
#  'origins',
#  'fox',
#  'schaeffler',
#  'statefarm',
#  'dealer',
#  'bosch',
#  'rexroth',
#  'mobily',
#  'xn--mgbb9fbpob',
#  'star',
#  'pid',
#  'contact',
#  'weber',
#  'analytics',
#  'jmp',
#  'xn--jlq61u9w7b',
#  'sas',
#  'ford',
#  'storage',
#  'lincoln',
#  'kfh',
#  'wanggou',
#  'shell',
#  'xn--pbt977c',
#  'xn--kpu716f',
#  'kpn',
#  'xn--ngbe9e0a',
#  'travelersinsurance',
#  'watches',
#  'xn--eckvdtc9d',
#  'tushu',
#  'trv',
#  'redumbrella',
#  'xn--mgbt3dhd',
#  'pars',
#  'zero',
#  'smile',
#  'bot',
#  'joy',
#  'buy',
#  'got',
#  'fast',
#  'jot',
#  'pin',
#  'read',
#  'circle',
#  'book',
#  'safe',
#  'call',
#  'room',
#  'like',
#  'author',
#  'travelers',
#  'nowruz',
#  'firestone',
#  'tci',
#  'sharp',
#  'salon',
#  'shia',
#  'insurance',
#  'norton',
#  'med',
#  'symantec',
#  'sfr',
#  'boehringer',
#  'bostik',
#  'lamborghini',
#  'bugatti',
#  'audi',
#  'vip',
#  'verisign',
#  'broadway',
#  'comsec',
#  'grainger',
#  'tab',
#  'fairwinds',
#  'cityeats',
#  'lifestyle',
#  'creditunion',
#  'vana',
#  'playstation',
#  'ferrero',
#  'rocher',
#  'apple',
#  'aarp',
#  'beats',
#  'ping',
#  'meo',
#  'sapo',
#  'sbs',
#  'gucci',
#  'landrover',
#  'jaguar',
#  'rwe',
#  'zara',
#  'mutuelle',
#  'arte',
#  'aramco',
#  'xn--mgba3a3ejt',
#  'dell',
#  'cipriani',
#  'kinder',
#  'yamaxun',
#  'moi',
#  'virgin',
#  'mtr',
#  'clubmed',
#  'bom',
#  'stockholm',
#  'kia',
#  'final',
#  'seven',
#  'hyundai',
#  'obi',
#  'ltd',
#  'bms',
#  'security',
#  'linde',
#  'stada',
#  'theatre',
#  'protection',
#  'car',
#  'csc',
#  'amica',
#  'stc',
#  'viva',
#  'stcgroup',
#  'aaa',
#  'gea',
#  'aco',
#  'xn--efvy88h',
#  'mom',
#  'family',
#  'seek',
#  'fage',
#  'ceb',
#  'group',
#  'giving',
#  'xperia',
#  'boots',
#  'chanel',
#  'wine',
#  'vin',
#  'lixil',
#  'xn--tckwe',
#  'xn--fhbei',
#  'xn--c2br7g',
#  'xn--9dbq2a',
#  'xn--11b4c3d',
#  'xn--3pxu8k',
#  'xn--t60b56a',
#  'xn--j1aef',
#  'xn--pssy2u',
#  'xn--42c2d9a',
#  'xn--mk1bu44c',
#  'ipiranga',
#  'lexus',
#  'pet',
#  'man',
#  'toyota',
#  'sanofi',
#  'tatamotors',
#  'srl',
#  'bet',
#  'ice',
#  'itau',
#  'nokia',
#  'lancaster',
#  'ubs',
#  'istanbul',
#  'delta',
#  'ist',
#  'hsbc',
#  'iinet',
#  'orange',
#  'bentley',
#  'game',
#  'jprs',
#  'bcn',
#  'studio',
#  'barcelona',
#  'airtel',
#  'live',
#  'app',
#  'sakura',
#  'realty',
#  'forum',
#  'hoteles',
#  'telefonica',
#  'bnl',
#  'cloud',
#  'bradesco',
#  'movistar',
#  'omega',
#  'swatch',
#  'law',
#  'skype',
#  'scor',
#  'office',
#  'starhub',
#  'vista',
#  'commbank',
#  'vistaprint',
#  'ricoh',
#  'netbank',
#  'cba',
#  'genting',
#  'drive',
#  'play',
#  'aeg',
#  'crown',
#  'statoil',
#  'bharti',
#  'lasalle',
#  'jlc',
#  'microsoft',
#  'hotmail',
#  'windows',
#  'bing',
#  'azure',
#  'homedepot',
#  'xbox',
#  'sncf',
#  'bible',
#  'ski',
#  'xn--imr513n',
#  'walter',
#  'sandvik',
#  'sandvikcoromant',
#  'bbva',
#  'mba',
#  'jll',
#  'fyi',
#  'thd',
#  'men',
#  'lupin',
#  'corsica',
#  'cisco',
#  'earth',
#  'soccer',
#  'coupons',
#  'icbc',
#  'brother',
#  'accenture',
#  'philips',
#  'xn--fjq720a',
#  'nec',
#  'taxi',
#  'xn--estv75g',
#  'hockey',
#  'run',
#  'theater',
#  'aig',
#  'icu',
#  'lol',
#  'liaison',
#  'cfa',
#  'nadex',
#  'cars',
#  'auto',
#  'toray',
#  'hitachi',
#  'bridgestone',
#  'sener',
#  'rent',
#  'honda',
#  'swiss',
#  'dog',
#  'broker',
#  'abb',
#  'sex',
#  'seat',
#  'weir',
#  'jewelry',
#  'xerox',
#  'show',
#  'team',
#  'sony',
#  'xn--kcrx77d1x4a',
#  'express',
#  'bauhaus',
#  'cafe',
#  'cyou',
#  'racing',
#  'xn--nyqy26a',
#  'scholarships',
#  'love',
#  'xn--30rr7y',
#  'mma',
#  'afl',
#  'redstone',
#  'xn--9et52u',
#  'bond',
#  'sap',
#  'komatsu',
#  'doha',
#  'mtn',
#  'review',
#  'win',
#  'panerai',
#  'download',
#  'movie',
#  'faith',
#  'tickets',
#  'accountant',
#  'loan',
#  'date',
#  'tours',
#  'ads',
#  'plus',
#  'film',
#  'gold',
#  'golf',
#  'guge',
#  'bbc',
#  'tech',
#  'news',
#  'xn--vuq861b',
#  'page',
#  'piaget',
#  'site',
#  'fan',
#  'online',
#  'cfd',
#  'trading',
#  'spreadbetting',
#  'erni',
#  'markets',
#  'forex',
#  'xin',
#  'pictet',
#  'abbott',
#  'nissan',
#  'infiniti',
#  'datsun',
#  'mtpc',
#  'oracle',
#  'goo',
#  'leclerc',
#  'java',
#  'epson',
#  'maif',
#  'xn--mxtq1m',
#  'sucks',
#  'study',
#  'boats',
#  'courses',
#  'casino',
#  'fans',
#  'football',
#  'goldpoint',
#  'school',
#  'yodobashi',
#  'cbn',
#  'gdn',
#  'apartments',
#  'saxo',
#  'nico',
#  'tennis',
#  'bingo',
#  'canon',
#  'style',
#  'toshiba',
#  'chat',
#  'ntt',
#  'kyoto',
#  'dclk',
#  'xn--b4w605ferd',
#  'ifm',
#  'goog',
#  'temasek',
#  'hangout',
#  'barclays',
#  'design',
#  'dabur',
#  'hermes',
#  'barclaycard',
#  'jcb',
#  'one',
#  'lotte',
#  'marriott',
#  'fit',
#  'lat',
#  'kddi',
#  'bank',
#  'shriram',
#  'zuerich',
#  'flowers',
#  'ggee',
#  'sale',
#  'amsterdam',
#  'video',
#  'docs',
#  'tires',
#  'dev',
#  'schwarz',
#  'iwc',
#  'osaka',
#  'sew',
#  'garden',
#  'lidl',
#  'doosan',
#  'sky',
#  'cartier',
#  'samsung',
#  'xn--czrs0t',
#  'adult',
#  'porn',
#  'trust',
#  'eurovision',
#  'fashion',
#  'latrobe',
#  'irish',
#  'xn--hxt814e',
#  'aquarelle',
#  'memorial',
#  'legal',
#  'money',
#  'coach',
#  'everbank',
#  'xn--flw351e',
#  'madrid',
#  'firmdale',
#  'xn--qcka1pmc',
#  'mormon',
#  'lds',
#  'party',
#  'xn--45q11c',
#  'cricket',
#  'science',
#  'reit',
#  'android',
#  'sydney',
#  'bloomberg',
#  'energy',
#  'delivery',
#  'taipei',
#  'emerck',
#  'flsmidth',
#  'band',
#  'yoga',
#  'crs',
#  'abogado',
#  'rip',
#  'wedding',
#  'poker',
#  'alsace',
#  'allfinanz',
#  'ibm',
#  'forsale',
#  'xn--vermgensberatung-pwb',
#  'xn--vermgensberater-ctb',
#  'xn--p1acf',
#  'tui',
#  'dvag',
#  'pohl',
#  'work',
#  'casa',
#  'budapest',
#  'world',
#  'google',
#  'fly',
#  'nexus',
#  'channel',
#  'prof',
#  'gle',
#  'zip',
#  'cal',
#  'chrome',
#  'wme',
#  'pharmacy',
#  'gmx',
#  'boo',
#  'dad',
#  'day',
#  'frl',
#  'ing',
#  'new',
#  'mov',
#  'rsvp',
#  'eat',
#  'meme',
#  'youtube',
#  'here',
#  'prod',
#  'esq',
#  'immo',
#  'pizza',
#  'gmail',
#  'gbiz',
#  'otsuka',
#  'business',
#  'xn--vhquv',
#  'network',
#  'click',
#  'diet',
#  'how',
#  'ooo',
#  'uol',
#  'help',
#  'hosting',
#  'property',
#  'ltda',
#  'cern',
#  'caravan',
#  'sca',
#  'xn--xhq521b',
#  'xn--1qqw23a',
#  'bnpparibas',
#  'restaurant',
#  'cymru',
#  'sarl',
#  'gifts',
#  'wales',
#  'tatar',
#  'top',
#  'healthcare',
#  'realtor',
#  'williamhill',
#  'ong',
#  'praxi',
#  'yandex',
#  'auction',
#  'whoswho',
#  'krd',
#  'ngo',
#  'nra',
#  'spiegel',
#  'lacaixa',
#  'lgbt',
#  'gent',
#  'nrw',
#  'scb',
#  'deals',
#  'melbourne',
#  'city',
#  'schmidt',
#  'cuisinella',
#  'cancerresearch',
#  'direct',
#  'place',
#  'suzuki',
#  'active',
#  'mini',
#  'bmw',
#  'ovh',
#  'capetown',
#  'physio',
#  'lotto',
#  'durban',
#  'green',
#  'joburg',
#  'vlaanderen',
#  'brussels',
#  'surf',
#  'xn--kput3i',
#  'bzh',
#  'scot',
#  'organic',
#  'global',
#  'engineer',
#  'nhk',
#  'hamburg',
#  'rehab',
#  'tirol',
#  'republican',
#  'gives',
#  'navy',
#  'army',
#  'bio',
#  'lawyer',
#  'vet',
#  'mortgage',
#  'software',
#  'host',
#  'market',
#  'dentist',
#  'hiv',
#  'attorney',
#  'press',
#  'degree',
#  'space',
#  'website',
#  'xn--4gbrim',
#  'yachts',
#  'rio',
#  'homes',
#  'autos',
#  'versicherung',
#  'reise',
#  'motorcycles',
#  'xn--czr694b',
#  'guide',
#  'audio',
#  'hiphop',
#  'loans',
#  'church',
#  'life',
#  'beer',
#  'juegos',
#  'luxe',
#  'credit',
#  'accountants',
#  'digital',
#  'claims',
#  'gmo',
#  'globo',
#  'bayern',
#  'airforce',
#  'creditcard',
#  'insure',
#  'finance',
#  'wtc',
#  'citic',
#  'xn--80adxhks',
#  'moscow',
#  'limited',
#  'fail',
#  'exchange',
#  'tax',
#  'wtf',
#  'fund',
#  'surgery',
#  'investments',
#  'financial',
#  'gratis',
#  'furniture',
#  'dental',
#  'care',
#  'cash',
#  'discount',
#  'blackfriday',
#  'clinic',
#  'fitness',
#  'schule',
#  'foo',
#  'soy',
#  'paris',
#  'frogans',
#  ...]

# %% [markdown]
# ### pickleに保存

# %%
with open("new_gTLD.pickle", "wb") as f:
    pickle.dump(NEW_TLD, f)

# %% [markdown]
# ### http://data.iana.org/TLD/tlds-alpha-by-domain.txt よりTLDの一覧を入手（基本的にはこれだけで良さそう？）

# %%
TLD = []
with open("./TLD.txt", "r") as f:
    line = f.readline()
    while line:
        TLD.append(line[:-1].lower())
        line = f.readline()
TLD = TLD[1:]

# %%
TLD
# Out:
# ['aaa',
#  'aarp',
#  'abarth',
#  'abb',
#  'abbott',
#  'abbvie',
#  'abc',
#  'able',
#  'abogado',
#  'abudhabi',
#  'ac',
#  'academy',
#  'accenture',
#  'accountant',
#  'accountants',
#  'aco',
#  'active',
#  'actor',
#  'ad',
#  'adac',
#  'ads',
#  'adult',
#  'ae',
#  'aeg',
#  'aero',
#  'aetna',
#  'af',
#  'afamilycompany',
#  'afl',
#  'africa',
#  'ag',
#  'agakhan',
#  'agency',
#  'ai',
#  'aig',
#  'aigo',
#  'airbus',
#  'airforce',
#  'airtel',
#  'akdn',
#  'al',
#  'alfaromeo',
#  'alibaba',
#  'alipay',
#  'allfinanz',
#  'allstate',
#  'ally',
#  'alsace',
#  'alstom',
#  'am',
#  'americanexpress',
#  'americanfamily',
#  'amex',
#  'amfam',
#  'amica',
#  'amsterdam',
#  'analytics',
#  'android',
#  'anquan',
#  'anz',
#  'ao',
#  'aol',
#  'apartments',
#  'app',
#  'apple',
#  'aq',
#  'aquarelle',
#  'ar',
#  'arab',
#  'aramco',
#  'archi',
#  'army',
#  'arpa',
#  'art',
#  'arte',
#  'as',
#  'asda',
#  'asia',
#  'associates',
#  'at',
#  'athleta',
#  'attorney',
#  'au',
#  'auction',
#  'audi',
#  'audible',
#  'audio',
#  'auspost',
#  'author',
#  'auto',
#  'autos',
#  'avianca',
#  'aw',
#  'aws',
#  'ax',
#  'axa',
#  'az',
#  'azure',
#  'ba',
#  'baby',
#  'baidu',
#  'banamex',
#  'bananarepublic',
#  'band',
#  'bank',
#  'bar',
#  'barcelona',
#  'barclaycard',
#  'barclays',
#  'barefoot',
#  'bargains',
#  'baseball',
#  'basketball',
#  'bauhaus',
#  'bayern',
#  'bb',
#  'bbc',
#  'bbt',
#  'bbva',
#  'bcg',
#  'bcn',
#  'bd',
#  'be',
#  'beats',
#  'beauty',
#  'beer',
#  'bentley',
#  'berlin',
#  'best',
#  'bestbuy',
#  'bet',
#  'bf',
#  'bg',
#  'bh',
#  'bharti',
#  'bi',
#  'bible',
#  'bid',
#  'bike',
#  'bing',
#  'bingo',
#  'bio',
#  'biz',
#  'bj',
#  'black',
#  'blackfriday',
#  'blanco',
#  'blockbuster',
#  'blog',
#  'bloomberg',
#  'blue',
#  'bm',
#  'bms',
#  'bmw',
#  'bn',
#  'bnl',
#  'bnpparibas',
#  'bo',
#  'boats',
#  'boehringer',
#  'bofa',
#  'bom',
#  'bond',
#  'boo',
#  'book',
#  'booking',
#  'bosch',
#  'bostik',
#  'boston',
#  'bot',
#  'boutique',
#  'box',
#  'br',
#  'bradesco',
#  'bridgestone',
#  'broadway',
#  'broker',
#  'brother',
#  'brussels',
#  'bs',
#  'bt',
#  'budapest',
#  'bugatti',
#  'build',
#  'builders',
#  'business',
#  'buy',
#  'buzz',
#  'bv',
#  'bw',
#  'by',
#  'bz',
#  'bzh',
#  'ca',
#  'cab',
#  'cafe',
#  'cal',
#  'call',
#  'calvinklein',
#  'cam',
#  'camera',
#  'camp',
#  'cancerresearch',
#  'canon',
#  'capetown',
#  'capital',
#  'capitalone',
#  'car',
#  'caravan',
#  'cards',
#  'care',
#  'career',
#  'careers',
#  'cars',
#  'cartier',
#  'casa',
#  'case',
#  'caseih',
#  'cash',
#  'casino',
#  'cat',
#  'catering',
#  'catholic',
#  'cba',
#  'cbn',
#  'cbre',
#  'cbs',
#  'cc',
#  'cd',
#  'ceb',
#  'center',
#  'ceo',
#  'cern',
#  'cf',
#  'cfa',
#  'cfd',
#  'cg',
#  'ch',
#  'chanel',
#  'channel',
#  'charity',
#  'chase',
#  'chat',
#  'cheap',
#  'chintai',
#  'christmas',
#  'chrome',
#  'chrysler',
#  'church',
#  'ci',
#  'cipriani',
#  'circle',
#  'cisco',
#  'citadel',
#  'citi',
#  'citic',
#  'city',
#  'cityeats',
#  'ck',
#  'cl',
#  'claims',
#  'cleaning',
#  'click',
#  'clinic',
#  'clinique',
#  'clothing',
#  'cloud',
#  'club',
#  'clubmed',
#  'cm',
#  'cn',
#  'co',
#  'coach',
#  'codes',
#  'coffee',
#  'college',
#  'cologne',
#  'com',
#  'comcast',
#  'commbank',
#  'community',
#  'company',
#  'compare',
#  'computer',
#  'comsec',
#  'condos',
#  'construction',
#  'consulting',
#  'contact',
#  'contractors',
#  'cooking',
#  'cookingchannel',
#  'cool',
#  'coop',
#  'corsica',
#  'country',
#  'coupon',
#  'coupons',
#  'courses',
#  'cr',
#  'credit',
#  'creditcard',
#  'creditunion',
#  'cricket',
#  'crown',
#  'crs',
#  'cruise',
#  'cruises',
#  'csc',
#  'cu',
#  'cuisinella',
#  'cv',
#  'cw',
#  'cx',
#  'cy',
#  'cymru',
#  'cyou',
#  'cz',
#  'dabur',
#  'dad',
#  'dance',
#  'data',
#  'date',
#  'dating',
#  'datsun',
#  'day',
#  'dclk',
#  'dds',
#  'de',
#  'deal',
#  'dealer',
#  'deals',
#  'degree',
#  'delivery',
#  'dell',
#  'deloitte',
#  'delta',
#  'democrat',
#  'dental',
#  'dentist',
#  'desi',
#  'design',
#  'dev',
#  'dhl',
#  'diamonds',
#  'diet',
#  'digital',
#  'direct',
#  'directory',
#  'discount',
#  'discover',
#  'dish',
#  'diy',
#  'dj',
#  'dk',
#  'dm',
#  'dnp',
#  'do',
#  'docs',
#  'doctor',
#  'dodge',
#  'dog',
#  'doha',
#  'domains',
#  'dot',
#  'download',
#  'drive',
#  'dtv',
#  'dubai',
#  'duck',
#  'dunlop',
#  'duns',
#  'dupont',
#  'durban',
#  'dvag',
#  'dvr',
#  'dz',
#  'earth',
#  'eat',
#  'ec',
#  'eco',
#  'edeka',
#  'edu',
#  'education',
#  'ee',
#  'eg',
#  'email',
#  'emerck',
#  'energy',
#  'engineer',
#  'engineering',
#  'enterprises',
#  'epost',
#  'epson',
#  'equipment',
#  'er',
#  'ericsson',
#  'erni',
#  'es',
#  'esq',
#  'estate',
#  'esurance',
#  'et',
#  'etisalat',
#  'eu',
#  'eurovision',
#  'eus',
#  'events',
#  'everbank',
#  'exchange',
#  'expert',
#  'exposed',
#  'express',
#  'extraspace',
#  'fage',
#  'fail',
#  'fairwinds',
#  'faith',
#  'family',
#  'fan',
#  'fans',
#  'farm',
#  'farmers',
#  'fashion',
#  'fast',
#  'fedex',
#  'feedback',
#  'ferrari',
#  'ferrero',
#  'fi',
#  'fiat',
#  'fidelity',
#  'fido',
#  'film',
#  'final',
#  'finance',
#  'financial',
#  'fire',
#  'firestone',
#  'firmdale',
#  'fish',
#  'fishing',
#  'fit',
#  'fitness',
#  'fj',
#  'fk',
#  'flickr',
#  'flights',
#  'flir',
#  'florist',
#  'flowers',
#  'fly',
#  'fm',
#  'fo',
#  'foo',
#  'food',
#  'foodnetwork',
#  'football',
#  'ford',
#  'forex',
#  'forsale',
#  'forum',
#  'foundation',
#  'fox',
#  'fr',
#  'free',
#  'fresenius',
#  'frl',
#  'frogans',
#  'frontdoor',
#  'frontier',
#  'ftr',
#  'fujitsu',
#  'fujixerox',
#  'fun',
#  'fund',
#  'furniture',
#  'futbol',
#  'fyi',
#  'ga',
#  'gal',
#  'gallery',
#  'gallo',
#  'gallup',
#  'game',
#  'games',
#  'gap',
#  'garden',
#  'gb',
#  'gbiz',
#  'gd',
#  'gdn',
#  'ge',
#  'gea',
#  'gent',
#  'genting',
#  'george',
#  'gf',
#  'gg',
#  'ggee',
#  'gh',
#  'gi',
#  'gift',
#  'gifts',
#  'gives',
#  'giving',
#  'gl',
#  'glade',
#  'glass',
#  'gle',
#  'global',
#  'globo',
#  'gm',
#  'gmail',
#  'gmbh',
#  'gmo',
#  'gmx',
#  'gn',
#  'godaddy',
#  'gold',
#  'goldpoint',
#  'golf',
#  'goo',
#  'goodyear',
#  'goog',
#  'google',
#  'gop',
#  'got',
#  'gov',
#  'gp',
#  'gq',
#  'gr',
#  'grainger',
#  'graphics',
#  'gratis',
#  'green',
#  'gripe',
#  'grocery',
#  'group',
#  'gs',
#  'gt',
#  'gu',
#  'guardian',
#  'gucci',
#  'guge',
#  'guide',
#  'guitars',
#  'guru',
#  'gw',
#  'gy',
#  'hair',
#  'hamburg',
#  'hangout',
#  'haus',
#  'hbo',
#  'hdfc',
#  'hdfcbank',
#  'health',
#  'healthcare',
#  'help',
#  'helsinki',
#  'here',
#  'hermes',
#  'hgtv',
#  'hiphop',
#  'hisamitsu',
#  'hitachi',
#  'hiv',
#  'hk',
#  'hkt',
#  'hm',
#  'hn',
#  'hockey',
#  'holdings',
#  'holiday',
#  'homedepot',
#  'homegoods',
#  'homes',
#  'homesense',
#  'honda',
#  'honeywell',
#  'horse',
#  'hospital',
#  'host',
#  'hosting',
#  'hot',
#  'hoteles',
#  'hotels',
#  'hotmail',
#  'house',
#  'how',
#  'hr',
#  'hsbc',
#  'ht',
#  'hu',
#  'hughes',
#  'hyatt',
#  'hyundai',
#  'ibm',
#  'icbc',
#  'ice',
#  'icu',
#  'id',
#  'ie',
#  'ieee',
#  'ifm',
#  'ikano',
#  'il',
#  'im',
#  'imamat',
#  'imdb',
#  'immo',
#  'immobilien',
#  'in',
#  'inc',
#  'industries',
#  'infiniti',
#  'info',
#  'ing',
#  'ink',
#  'institute',
#  'insurance',
#  'insure',
#  'int',
#  'intel',
#  'international',
#  'intuit',
#  'investments',
#  'io',
#  'ipiranga',
#  'iq',
#  'ir',
#  'irish',
#  'is',
#  'iselect',
#  'ismaili',
#  'ist',
#  'istanbul',
#  'it',
#  'itau',
#  'itv',
#  'iveco',
#  'jaguar',
#  'java',
#  'jcb',
#  'jcp',
#  'je',
#  'jeep',
#  'jetzt',
#  'jewelry',
#  'jio',
#  'jll',
#  'jm',
#  'jmp',
#  'jnj',
#  'jo',
#  'jobs',
#  'joburg',
#  'jot',
#  'joy',
#  'jp',
#  'jpmorgan',
#  'jprs',
#  'juegos',
#  'juniper',
#  'kaufen',
#  'kddi',
#  'ke',
#  'kerryhotels',
#  'kerrylogistics',
#  'kerryproperties',
#  'kfh',
#  'kg',
#  'kh',
#  'ki',
#  'kia',
#  'kim',
#  'kinder',
#  'kindle',
#  'kitchen',
#  'kiwi',
#  'km',
#  'kn',
#  'koeln',
#  'komatsu',
#  'kosher',
#  'kp',
#  'kpmg',
#  'kpn',
#  'kr',
#  'krd',
#  'kred',
#  'kuokgroup',
#  'kw',
#  'ky',
#  'kyoto',
#  'kz',
#  'la',
#  'lacaixa',
#  'ladbrokes',
#  'lamborghini',
#  'lamer',
#  'lancaster',
#  'lancia',
#  'lancome',
#  'land',
#  'landrover',
#  'lanxess',
#  'lasalle',
#  'lat',
#  'latino',
#  'latrobe',
#  'law',
#  'lawyer',
#  'lb',
#  'lc',
#  'lds',
#  'lease',
#  'leclerc',
#  'lefrak',
#  'legal',
#  'lego',
#  'lexus',
#  'lgbt',
#  'li',
#  'liaison',
#  'lidl',
#  'life',
#  'lifeinsurance',
#  'lifestyle',
#  'lighting',
#  'like',
#  'lilly',
#  'limited',
#  'limo',
#  'lincoln',
#  'linde',
#  'link',
#  'lipsy',
#  'live',
#  'living',
#  'lixil',
#  'lk',
#  'llc',
#  'loan',
#  'loans',
#  'locker',
#  'locus',
#  'loft',
#  'lol',
#  'london',
#  'lotte',
#  'lotto',
#  'love',
#  'lpl',
#  'lplfinancial',
#  'lr',
#  'ls',
#  'lt',
#  'ltd',
#  'ltda',
#  'lu',
#  'lundbeck',
#  'lupin',
#  'luxe',
#  'luxury',
#  'lv',
#  'ly',
#  'ma',
#  'macys',
#  'madrid',
#  'maif',
#  'maison',
#  'makeup',
#  'man',
#  'management',
#  'mango',
#  'map',
#  'market',
#  'marketing',
#  'markets',
#  'marriott',
#  'marshalls',
#  'maserati',
#  'mattel',
#  'mba',
#  'mc',
#  'mckinsey',
#  'md',
#  'me',
#  'med',
#  'media',
#  'meet',
#  'melbourne',
#  'meme',
#  'memorial',
#  'men',
#  'menu',
#  'merckmsd',
#  'metlife',
#  'mg',
#  'mh',
#  'miami',
#  'microsoft',
#  'mil',
#  'mini',
#  'mint',
#  'mit',
#  'mitsubishi',
#  'mk',
#  'ml',
#  'mlb',
#  'mls',
#  'mm',
#  'mma',
#  'mn',
#  'mo',
#  'mobi',
#  'mobile',
#  'mobily',
#  'moda',
#  'moe',
#  'moi',
#  'mom',
#  'monash',
#  'money',
#  'monster',
#  'mopar',
#  'mormon',
#  'mortgage',
#  'moscow',
#  'moto',
#  'motorcycles',
#  'mov',
#  'movie',
#  'movistar',
#  'mp',
#  'mq',
#  'mr',
#  'ms',
#  'msd',
#  'mt',
#  'mtn',
#  'mtr',
#  'mu',
#  'museum',
#  'mutual',
#  'mv',
#  'mw',
#  'mx',
#  'my',
#  'mz',
#  'na',
#  'nab',
#  'nadex',
#  'nagoya',
#  'name',
#  'nationwide',
#  'natura',
#  'navy',
#  'nba',
#  'nc',
#  'ne',
#  'nec',
#  'net',
#  'netbank',
#  'netflix',
#  'network',
#  'neustar',
#  'new',
#  'newholland',
#  'news',
#  'next',
#  'nextdirect',
#  'nexus',
#  'nf',
#  'nfl',
#  'ng',
#  'ngo',
#  'nhk',
#  'ni',
#  'nico',
#  'nike',
#  'nikon',
#  'ninja',
#  'nissan',
#  'nissay',
#  'nl',
#  'no',
#  'nokia',
#  'northwesternmutual',
#  'norton',
#  'now',
#  'nowruz',
#  'nowtv',
#  'np',
#  'nr',
#  'nra',
#  'nrw',
#  'ntt',
#  'nu',
#  'nyc',
#  'nz',
#  'obi',
#  'observer',
#  'off',
#  'office',
#  'okinawa',
#  'olayan',
#  'olayangroup',
#  'oldnavy',
#  'ollo',
#  'om',
#  'omega',
#  'one',
#  'ong',
#  'onl',
#  'online',
#  'onyourside',
#  'ooo',
#  'open',
#  'oracle',
#  'orange',
#  'org',
#  'organic',
#  'origins',
#  'osaka',
#  'otsuka',
#  'ott',
#  'ovh',
#  'pa',
#  'page',
#  'panasonic',
#  'paris',
#  'pars',
#  'partners',
#  'parts',
#  'party',
#  'passagens',
#  'pay',
#  'pccw',
#  'pe',
#  'pet',
#  'pf',
#  'pfizer',
#  'pg',
#  'ph',
#  'pharmacy',
#  'phd',
#  'philips',
#  'phone',
#  'photo',
#  'photography',
#  'photos',
#  'physio',
#  'piaget',
#  'pics',
#  'pictet',
#  'pictures',
#  'pid',
#  'pin',
#  'ping',
#  'pink',
#  'pioneer',
#  'pizza',
#  'pk',
#  'pl',
#  'place',
#  'play',
#  'playstation',
#  'plumbing',
#  'plus',
#  'pm',
#  'pn',
#  'pnc',
#  'pohl',
#  'poker',
#  'politie',
#  'porn',
#  'post',
#  'pr',
#  'pramerica',
#  'praxi',
#  'press',
#  'prime',
#  'pro',
#  'prod',
#  'productions',
#  'prof',
#  'progressive',
#  'promo',
#  'properties',
#  'property',
#  'protection',
#  'pru',
#  'prudential',
#  'ps',
#  'pt',
#  'pub',
#  'pw',
#  ...]

# %%
len(TLD) # TLDは1536個
# Out:
# 1536

# %%
set(NEW_TLD) - set(TLD) # 一方で、ICANNから入手したnew gTLDとの差分があるため完全ではないかもしれない
# Out:
# {'boots',
#  'doosan',
#  'flsmidth',
#  'goodhands',
#  'iinet',
#  'iwc',
#  'jlc',
#  'meo',
#  'mtpc',
#  'mutuelle',
#  'orientexpress',
#  'panerai',
#  'sapo',
#  'telecity',
#  'vista',
#  'xperia'}
